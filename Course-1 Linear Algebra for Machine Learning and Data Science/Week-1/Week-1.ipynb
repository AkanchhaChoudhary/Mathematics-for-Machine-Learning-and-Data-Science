# %% [markdown]
# # Week-1 of Course 1-Linear Algebra for Machine Learning #

# %% [markdown]
# ## Table of Contents ##
#
# - System of sentences
# - System of equations
# - Linear Equations
# - A geometric notion of singularity
# - Singular vs nonsingular matrices
# - Linear dependence and independence
# - The determinant

# %% [markdown]
# <a name='0'></a>
# ## Machine Learning motivation. ##
#
#
# Linear Algebra has many application in field of science & technology.It has widespread field in machine learning.Neural Network is one of the most popular and basic application of ML.This popular model takes the image pixels as input and performs many arithemetic operation on theese values in order to get a final value which indicates that the neural network thinks the image is face or not.

# %% [markdown]
# ## Use of Linear ALgebra in Neural Networks ##
#
#
#
#
# ![Screenshot from 2023-03-26 15-01-30.png](attachment:92a3ea66-496c-4a0e-9220-ed0006a9e121.png)
#
#
#
#
# Neural networks has many nodes arranged in layers.Those are nodes of neural network and they are meant to loosely mimic the behaviours of the brain.Surprisingly these layers can be expressed as rectangular arrays of numbers which are called matrices .Matrices are one of the building blocks of Machine Learning.

# %% [markdown]
# # System of sentences and its types #

# %% [markdown]
# Mathematics is the core of ML.Linear equations of Linear Algebra is one important topic and to unserstand those equations its important to understand languages of mathematics.Sentences are helpful in understanding the information they are hiding which is furthure converted into equations then to matrix and so on.Look at the sentences below
# ![Screenshot from 2023-03-26 15-27-15.png](attachment:7a65b813-e10d-4a5e-a1b0-a0a93c86f2b3.png)

# %% [markdown]
# Here in system 1 there are three sentences and each gives different information.This is called Complete and Nonsingular system.
# In system 2 and three the same information is repeated and its called Redudant and Singular.
# In system 3 the information given by sentence contradicts and its called Contradictory and Singular.

# %% [markdown]
# # System of equation and its types #

# %% [markdown]
# Below is an example how a system of sentences is converted to system of equation.
#
# ![Screenshot from 2023-03-26 15-35-48.png](attachment:c37948d3-fb21-4b30-a1d5-fdb2728907cc.png)

# %% [markdown]
# Depending on how and in what way a sentences gives information a system of equation can be categorised.Either  Complete(Non-singular) or redudant(singular) or contadictory(SIngular)

# %% [markdown]
# # Linear equations and its representation in form of lines #

# %% [markdown]
# Linear equations are very important.They are not compicated .We can do many things with them such as manipulating and extracting information out of them.Linear equation have simple scalers.On ther hand scalers of Non-Linear equations are complicated.their scalers can besquares,sine,cosine,tangent,arctan,powers or logarithm
# ![Screenshot from 2023-03-26 15-49-02.png](attachment:57a61ded-358b-4669-b768-6b5e1993c4fe.png)

# %% [markdown]
# # A geometric notion of singularity #

# %% [markdown]
# As you can see in above image:
# The system of equation that has unique solution( complete) intersect at one point.
# The system that has infinite solutions(redudant) overlap with each other .
# The sysem that has no solutions(contradictory) neither overlap not do intersect.
# Also note that constants in the system of linear equations are not important in order to determine if the system is singular or non-singular

# %% [markdown]
# # Singular vs nonsingular matrices #

# %% [markdown]
# When we talk about matrices ,we also talk about singularity and non-singularity of matrices.Matrices have lots of very important properties and they arise from many different places in math.
#
# ![Screenshot from 2023-03-26 16-01-04.png](attachment:ccb84db4-8eb3-4c68-8b93-660ad942baad.png)
#
#  If you take the coefficients of a and b and now put them in a two by two shaped box, which is called an array or a matrix. That's the matrix corresponding to the system.
#  Matrices are just like systems of linear equations can also be singular or non-singular.
#  Since the first system is non-singular because it has a unique solution, then we say that its corresponding matrix is non-singular. And since the second system is singular, as it has infinitely many solutions, we say that its corresponding matrix is singular.

# %% [markdown]
# # Linear dependence and independence #

# %% [markdown]
# Given three system of sentences or system of equation below,
#
#
# ![Screenshot from 2023-03-26 16-09-29.png](attachment:6904fafd-12c7-4030-8fd5-a128f61302e9.png)
#
#
# These systems are singular if second sentences carries same information as first or it is singular if the second carries same information as third.This is called LINEAR DEPENDENCE and this has a big role in Machine Learning.

# %% [markdown]
# # Determinant #

# %% [markdown]
# There is a faster way to tell if a matrix is singular or non singular and in this video you will learn it. It's called the determinant and it is a quick formula that returns a 0 if the matrix is singular and a number different from 0 if the matrix is non singular.
