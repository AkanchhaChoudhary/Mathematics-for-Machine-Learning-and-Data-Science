# %% [markdown]
# # Week-2 of Course 1-Linear Algebra for Machine Learning #
# This week l learnt how to solve systems of linear equations and how to manipulate matrix to vastly simplify them.

# %% [markdown]
# ## Table of Content ##
#
# - Neural Network-Sound recognition.
# - Solving non-singular system of linear equations.
# - Solving singular systems of linear equations.
# - Matrix row-reduction.
# - Row operations that preserve singularity.
# - The rank of a matrix.
# - Row echelon form.

# %% [markdown]
# ## Neural Network-Sound recognition ##
# This is another most known example for neural network.Neural networks can be trained to take other inputs, such as sound.A neural networks can transcribe a sound that person is speaking with high accuracy and also determine their tone if they are forming a question or statement.In acoustic monitoring,sound recognitionis used to track species through their sounds and acoustic data for the environment.It is very helpful to save in dangerous species and provide crucial information for researchers to map environmental changes through a large sound data.
# ![Screenshot from 2023-03-26 23-34-00.png](attachment:c3935362-5302-4b93-aa86-3bf26945d045.png)

# %% [markdown]
# # Solving non-singular system of linear equations #

# %% [markdown]
# In previous week we learnt how to form liear equations from system of sentences.Here we will learn how to solve that equations with below three process:
# 1.Manipulating equations
# 2.Swapping equations
# 3.Adding equations
# 4.Multiplying equations by a constant
#
#  ## Solving for  ##
#
# ![Screenshot from 2023-03-26 23-36-53.png](attachment:c8b422b9-e1c1-4e02-96bc-6de96c7e3586.png)
#
# These are independent equations means both equation have different information.This will have unique solution.But look at the equation below:
#
#
#
# ![Screenshot from 2023-03-27 00-44-41.png](attachment:fb776edf-4f29-4147-a04d-e0a784de754d.png)
#
# Well for these equations there's no manipulation you can do to remove only one of the variables because anything you do to remove one will also remove the other one because the system is singular. And again, this is because the second equation adds no value to the system.And we are ledt with just one degree of freedom.

# %% [markdown]
# ![Screenshot from 2023-03-27 00-53-06.png](attachment:fc83bcca-2d17-4a07-8f4b-d21c7db92c67.png)

# %% [markdown]
# # Matrix row-reduction #
